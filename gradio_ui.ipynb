# %% [markdown]
# ## <u><center><span style ="color:blue">Gradio UI for Optimizer</u></span></center>
# #### Per Shaw's Instructional Video ([here](https://www.youtube.com/watch?v=R5WXaxmb6m4)), there's no point in not taking this optimizer to the next level, giving it a UI for easier interaction
# #### For this, we'll be using Python's library, Gradio.
# ##### * Gradio is a Python library that helps creat interactive user interfaces (UI's) for ML models and Python functions.
# ##### * With it, you can create a web application pretty easily, without deep-diving into more extensive WebDev frameworks.

# %%
# imports
import gradio as gr

# import functions, a file created in the job folder that houses the functions Gradio needs to do its job
from new_functions import *
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 5
#       2 import gradio as gr
#       4 # import functions, a file created in the job folder that houses the functions Gradio needs to do its job
# ----> 5 from functions import *
#
# File ~/PromptEngineering/api_work/resume_project/jobapp_prompter/functions.py:243
#       1 {
#       2  "cells": [
#       3   {
#       4    "cell_type": "markdown",
#       5    "id": "5da53647-0105-4b55-8623-65244f4fac58",
#       6    "metadata": {},
#       7    "source": [
#       8     "## <u><span style=\"color:red\"><center>Functions File</span></u></center>\n",
#       9     "###### <center>Again, special thanks to Shaw Talebi, whose expertice has been more than instrumental in this!<center>\n",
#      10     "#### Since we're creating a Gradio UI, we'll need a place to store functions so they can be easily used.\n",
#      11     "##### This is that file."
#      12    ]
#      13   },
#      14   {
#      15    "cell_type": "code",
#      16    "execution_count": 5,
#      17    "id": "69c9ceed-0f34-4e45-9ed1-4ec34fcd3a44",
#      18    "metadata": {},
#      19    "outputs": [],
#      20    "source": [
#      21     "# imports\n",
#      22     "import os\n",
#      23     "from dotenv import load_dotenv\n",
#      24     "from openai import OpenAI\n",
#      25     "from markdown import markdown\n",
#      26     "from weasyprint import HTML\n",
#      27     "\n",
#      28     "# load dotenv\n",
#      29     "load_dotenv()\n",
#      30     "\n",
#      31     "# assign \"my_sk\" as global variable\n",
#      32     "my_sk = os.getenv(\"MY_SK\")"
#      33    ]
#      34   },
#      35   {
#      36    "cell_type": "code",
#      37    "execution_count": 6,
#      38    "id": "abd0bb51-fac0-43f7-b189-10528500a77b",
#      39    "metadata": {},
#      40    "outputs": [],
#      41    "source": [
#      42     "# prompt creator function - the lambda function from scratchpad\n",
#      43     "# basically, Steps 1, 2, and 3 from scratchpad\n",
#      44     "def prompt_creator(resume_string: str, job_desc_string: str) -> str:\n",
#      45     "    \"\"\"\n",
#      46     "    Using the prompt engineered in the scratchpad 'lambda' function, this function uses the power of ChatGPT's 4o-mini engine to\n",
#      47     "    act as a professional resume optimizer to take my existing resume and:\n",
#      48     "        1.) Use action-verbs and job posting keywords to optimize it for Applicant Tracking Systems;\n",
#      49     "        2.) Provide us with feedback on any changes that can be made to strengthen the resume; and \n",
#      50     "        3.) Format the adjusted, AI-assisted resume in a clean Markdown format\n",
#      51     "\n",
#      52     "    Args:\n",
#      53     "        resume_string (str): our existing resume text input\n",
#      54     "        job_desc_string (str): The target job description text\n",
#      55     "\n",
#      56     "    Returns:\n",
#      57     "        str: A formatted prompt string containing instructions for resume optimization\n",
#      58     "    \"\"\"\n",
#      59     "    return f\"\"\"\n",
#      60     "    ### Role: \n",
#      61     "    You are a professional resume optimization expert, tailoring my resume to fit specific job descriptions. \n",
#      62     "    You know my job preferences include collaborating with people, and helping businesses get the most out of their data.\n",
#      63     "    Your goal is to optimize my resume and provide actionable suggestions for improvement to align with the target role.\n",
#      64     "\n",
#      65     "    ### Guidelines:\n",
#      66     "    1. **Relevance**:\n",
#      67     "    - Prioritize the particular skills and experiences I have with what is **most relevant to the job position**.\n",
#      68     "    - De-emphasize or even completely remove irrelevant details to ensure a **concise** and **targeted** resume.\n",
#      69     "    - Limit work experience section to 2-3 most relevant roles\n",
#      70     "    - Limit bullet points under each role to 2-3 most relevant impacts\n",
#      71     "\n",
#      72     "    2. **Action-Driven Results**:\n",
#      73     "    - Choose **strong action verbs** and **quantifiable results** (eg: percentages, revenues, efficiency improvement, etc.)\n",
#      74     "\n",
#      75     "    3. **Keyword Optimization**:\n",
#      76     "    - Integrate **keywords** and phrases from the job description naturally to optimize for Applicant Tracking Systems (ATS)\n",
#      77     "\n",
#      78     "    4. **Additional Suggestions*** *(if gaps exist)*:\n",
#      79     "    - If the resume does not fully align with the job description, suggest:\n",
#      80     "        a.) **Additional technical or soft skills** that I could add to make my profile stronger.\n",
#      81     "        b.) **Certifications or courses** I have (or could pursue) that would bridge the gap(s).\n",
#      82     "        c.) **Project ideas or experiences** that would better align with the role.\n",
#      83     "\n",
#      84     "    5.) **Formatting**:\n",
#      85     "    - Ouptut the tailored resume in **clean Markdown format**.\n",
#      86     "    - Include an **\"Additional Suggestions\"** section at the end with actionable improvement recommendations.\n",
#      87     "\n",
#      88     "    ---\n",
#      89     "\n",
#      90     "    ## Input:\n",
#      91     "    - **My resume**:\n",
#      92     "    {resume_string}\n",
#      93     "\n",
#      94     "    - **The Job Description**:\n",
#      95     "    {job_desc_string}\n",
#      96     "\n",
#      97     "    ---\n",
#      98     "\n",
#      99     "    ### Output:\n",
#     100     "    1. **Tailored Resume**:\n",
#     101     "    - A resume in **Markdown format** that emphasizes relevant experience, skills, and achievements.\n",
#     102     "    - Incorporates job description **keywords** to optimize for ATS.\n",
#     103     "    - Uses confident language and is no longer than **one page**.\n",
#     104     "\n",
#     105     "    2. **Additional Suggestions** *(if applicable)*:\n",
#     106     "    - List **skills** that could strengthen alignment with the role.\n",
#     107     "    - Recommend **certifications or courses** to pursue.\n",
#     108     "    - Suggest **specific projects or experiences** to develop.\n",
#     109     "\"\"\""
#     110    ]
#     111   },
#     112   {
#     113    "cell_type": "code",
#     114    "execution_count": 4,
#     115    "id": "9e3380f2-1fdb-45f1-a6bc-1b0d5bcf5891",
#     116    "metadata": {},
#     117    "outputs": [],
#     118    "source": [
#     119     "# Step 4 from scratchpad\n",
#     120     "def get_resume_response(prompt: str, api_key: str, model: str = \"gpt-4o-mini\", temperature: float = 0.7) -> str:\n",
#     121     "    \"\"\"\n",
#     122     "    Now that we've got the resume optimized, we send it to OpenAI's API, where it sends us back the optimized\n",
#     123     "    resume response. \n",
#     124     "\n",
#     125     "    With this function, we:\n",
#     126     "    1.) set up our OpenAI client;\n",
#     127     "    2.) make an API call to OpenAI using the provided prompt; and \n",
#     128     "    3.) rerurns to us the generated resume response.\n",
#     129     "\n",
#     130     "    Args:\n",
#     131     "        prompt (str): The formatted prompt containing the resume and job description\n",
#     132     "        api_key (str): our OpenAI API key for call authentication\n",
#     133     "        model (\"gpt-4o-mini): The OpenAI engine to use. Here, we're hard-coding it to \"gpt-4o-mini\"\n",
#     134     "        temperature (float, optional): Controls randomness in the response. Hard-set to 0.7, a popular temperature setting.\n",
#     135     "\n",
#     136     "    Returns:\n",
#     137     "        str: The AI-generated optimized resume, along with the suggestions we need to make it stronger\n",
#     138     "\n",
#     139     "    Raises:\n",
#     140     "        OpenAIError: If there's an issue with the API call\n",
#     141     "    \"\"\"\n",
#     142     "    # set up api client\n",
#     143     "    open_apikey = os.environ.get(\"openapi_apikey\")\n",
#     144     "    \n",
#     145     "    client = OpenAI(api_key = open_apikey)\n",
#     146     "\n",
#     147     "    # make the call and set response variable to hold the all info we get back\n",
#     148     "    response = client.chat.completions.create(\n",
#     149     "    model = model,\n",
#     150     "    \n",
#     151     "    # set our roles up - think of casting a play: \"Today, the role of the Expert Resume Writer will be played by the system.\"\n",
#     152     "    messages = [\n",
#     153     "        {\"role\" : \"system\", \"content\" : \"Expert Resume Writer\"},\n",
#     154     "        {\"role\" : \"user\", \"content\" : prompt}\n",
#     155     "    ],\n",
#     156     "    \n",
#     157     "    # give it some creative license with our default 0.7 rating\n",
#     158     "    temperature = temperature\n",
#     159     ")\n",
#     160     "\n",
#     161     "    # extract and return our response\n",
#     162     "    return response.choices[0].message.content"
#     163    ]
#     164   },
#     165   {
#     166    "cell_type": "code",
#     167    "execution_count": 8,
#     168    "id": "aebc555c-5325-433d-8253-5e6b33faa4a5",
#     169    "metadata": {},
#     170    "outputs": [],
#     171    "source": [
#     172     "# Step 5 (more or less) from scratchpad\n",
#     173     "def process_resume(resume, job_desc_string):\n",
#     174     "    \"\"\"\n",
#     175     "    Compares the resume file against the job description to create an optimized version.\n",
#     176     "\n",
#     177     "    Args:\n",
#     178     "        resume (file): A file object containing the resume in markdown format\n",
#     179     "        job_desc_string (str): The job description text to optimize the resume against\n",
#     180     "\n",
#     181     "    Returns:\n",
#     182     "        tuple: A tuple containing three elements:\n",
#     183     "            - str: The optimized resume in markdown format (for display)\n",
#     184     "            - str: The same optimized resume (for editing)\n",
#     185     "            - str: Suggestions for improving the resume\n",
#     186     "    \"\"\"\n",
#     187     "    # read resume\n",
#     188     "    with open(resume, \"r\", encoding=\"utf-8\") as file:\n",
#     189     "        resume_string = file.read()\n",
#     190     "\n",
#     191     "    # create prompt\n",
#     192     "    prompt = create_prompt(resume_string, job_desc_string)\n",
#     193     "\n",
#     194     "    # generate response with the my_sk we globally set with load_dotenv() earlier\n",
#     195     "    response_string = get_resume_response(prompt, my_sk)\n",
#     196     "    response_list = response_string.split(\"## Additional Suggestions\")\n",
#     197     "    \n",
#     198     "    # extract new resume and suggestions for improvement\n",
#     199     "    new_resume = response_list[0]\n",
#     200     "    suggestions = \"## Additional Suggestions \\n\\n\" +response_list[1]\n",
#     201     "\n",
#     202     "    # the three resumes: the optimized resume, a version of that we can edit, and suggestions for improving it\n",
#     203     "    return new_resume, new_resume, suggestions"
#     204    ]
#     205   },
#     206   {
#     207    "cell_type": "code",
#     208    "execution_count": 9,
#     209    "id": "4d8973ac-5170-4fc2-aca6-1ca004995706",
#     210    "metadata": {},
#     211    "outputs": [],
#     212    "source": [
#     213     "# Steps 6 and 7 from scratchpad\n",
#     214     "def export_resume(new_resume):\n",
#     215     "    \"\"\"\n",
#     216     "    Takes the markdown resume, converts it to PDF format, and saves it.\n",
#     217     "\n",
#     218     "    Args:\n",
#     219     "        new_resume (str): The new, optimized resume content in markdown format\n",
#     220     "\n",
#     221     "    Returns:\n",
#     222     "        str: A message indicating success or failure of the PDF export\n",
#     223     "    \"\"\"\n",
#     224     "    try:\n",
#     225     "        # save as PDF\n",
#     226     "        output_pdf_file = \"resumes/nick_joseph_resume.pdf\"\n",
#     227     "\n",
#     228     "        \n",
#     229     "        # Convert Markdown to HTML\n",
#     230     "        html_content = markdown(new_resume)\n",
#     231     "        \n",
#     232     "        # Convert HTML to PDF and save\n",
#     233     "        HTML(string=html_content).write_pdf(output_pdf_file, stylesheets=['resumes/style.css'])\n",
#     234     "\n",
#     235     "        return f\"Successfully exported resume to {output_pdf_file} 🎉\"\n",
#     236     "    except Exception as e:\n",
#     237     "        return f\"Failed to export resume: {str(e)} 💔\"\n",
#     238     "        "
#     239    ]
#     240   },
#     241   {
#     242    "cell_type": "code",
# --> 243    "execution_count": null,
#     244    "id": "991b29db-597d-4b3e-93fa-0c72f09df6c1",
#     245    "metadata": {},
#     246    "outputs": [],
#     247    "source": []
#     248   }
#     249  ],
#     250  "metadata": {
#     251   "kernelspec": {
#     252    "display_name": "Python 3 (ipykernel)",
#     253    "language": "python",
#     254    "name": "python3"
#     255   },
#     256   "language_info": {
#     257    "codemirror_mode": {
#     258     "name": "ipython",
#     259     "version": 3
#     260    },
#     261    "file_extension": ".py",
#     262    "mimetype": "text/x-python",
#     263    "name": "python",
#     264    "nbconvert_exporter": "python",
#     265    "pygments_lexer": "ipython3",
#     266    "version": "3.10.4"
#     267   }
#     268  },
#     269  "nbformat": 4,
#     270  "nbformat_minor": 5
#     271 }
#
# NameError: name 'null' is not defined
