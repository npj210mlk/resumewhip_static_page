# %% [markdown]
# ### This notebook does the same thing as the <span style="color:orange">original</span>, only using <span style="color:blue">Google's 'gemini-2.0 flash'</span> engine instead of <span style="color:orange">OpenAI</span>.
# #### <u><span style="color:green">Two reasons you may want to try this</span></u>:
# ##### 1.) It's a good chance to compare how well each of the engines responds; and
# ##### 2.) You may exceed one rate limit (like I did), and need another service to continue moving forward.
#
# #### Before you do anything, you need to obtain your api key from <span style="color:blue">Google</span> so you can use <span style="color:blue">Gemini</span>.
# > ##### To do this, click [here](https://ai.google.dev/gemini-api/docs/api-key) and follow the steps.
# > ##### It will also help to run the following pip commands in your environment (you'll need them anyway):
# > ##### a.) <span style="color:red">pip install -q -U google-genai</span>; and
# > ##### b.) <span style="color:red">pip install google-generativeai</span>
#
# #### <u><b>Once you have that, you'll need the following imports</b></u>:
# ##### 1.) os - to access your api key from <b>a <i>safe location</i> elsewhere</b> on your computer;
# ##### 2.) dotenv - loads the environment variables from your .env file;
# ##### 3.) google.generativeai - connects you to <span style="color:blue">Google's Gemini </span> models;
# ##### 4.) markdown - converts markdown to html (helpful when building a web-app like this); and
# ##### 5.) display, Markdown - enriches your Jupyter texts (optional, but makes things more visually interesting)
# ***

# %%
import os
from dotenv import load_dotenv
import google.generativeai as genai
from markdown import markdown
from IPython.display import display, Markdown

# %% [markdown]
# ***
# #### Make the destination directory 'google_resumes' to send the <span style="color:blue">Gemini</span> work results
# ***

# %%
os.makedirs("google_resumes", exist_ok=True)

# %% [markdown]
# ***
# #### There is <i>one other library</i> you'll want to import: [<span style="color:green">weasyprint</span>](weasyprint.org).
#
# #### Weasy's been a thorn in my side every time I've used it.
# #### It's a brew install (<span style="color:green">great</span>), but only partly(<span style="color:red">not so great</span>).
# #### I've documented the headaches and ways around them in the <span style="color:orange">OpenAI</span> notebook, so no need to cry about them here, too.
# #### It's uniquely powerful, so I say use it, <i><b>but...</i></b>: you may want to have some Advil ready.
# ***

# %%
from weasyprint import HTML

# %% [markdown]
# #### Okay, looks like all the imports are working.
#
# #### Like the <span style="color:orange">OpenAI notebook</span>, I had my original resume converted to a Markdown file.
# #### In that notebook, it was done through ChatGPT with a simple 'convert-this-to-markdown' kind of prompt.
# #### I will do the same for this <span style="color:blue">Gemini</span> notebook as well, but using <span style="color:blue">Gemini</span> instead of ChatGPT.
# #### Reason being, <span style="color:blue">Gemini</span> will be talking to <span style="color:blue">Gemini</span> (and we can't have these two kids fighting).
# ***
# #### <u>With that done, I'll be following the same steps as in the <span style="color:orange">OpenAI</span> notebook</u>:
# ##### 1.) Open and read the markdown resume file;
# ##### 2.) Input the desired job description;
# ##### 3.) Template some prompt engineering;
# ##### 4.) Generate the resume with <span style="color:blue">Gemini</span>;
# ##### 5.) See the results;
# ##### 6.) Save the new resume; and
# ##### 7.) Display suggestions for improvement.
# ***

# %% [markdown]
# ### Step 1: Open and Read the Markdown Resume File
# ***

# %%
with open("/Users/nicholasjoseph/Desktop/nj_gemini_pm_res.md", "r", encoding = "utf-8") as resume_file:
    resume_string = resume_file.read()

# check to see if it worked:
# display(Markdown(resume_string))

# ^^ reads just fine.

# %% [markdown]
# ### Step 2: Input the Desired Job Description
# #### Again, this is a "copy/paste" input directly from the job description; progress will stop until you fill it in.
# ***

# %%
job_desc_string = input()
# Out:
#  About the job We are looking for a Technical Product Manager who will help to own the roadmap and drive feature delivery for our developer SDK products. The right person will not only have a technical acumen, but can translate business needs into requirements that enable a development team to create the best solution for Apryse’s current and future customers. If you're creative, goal-driven and hands-on, and you like working with a smart, talented, generally awesome team, we'd love to hear from you!  Responsibilities:   Gain a deep understanding of Apryse's document processing SDKs and customer use cases to build empathy for the developer and the problems our product solves.   Collaborate with the engineering team to assess technical feasibility, identify potential limitations, and propose innovative solutions that address the most important issues facing developers.   Define and prioritize product features and enhancements based on business value, customer feedback, and technical feasibility by working closely with the engineering team to define product requirements, user stories, and acceptance criteria.   Define and prioritize product features and bugs in through an agile development process, ensuring timely delivery of high-quality product releases.   Provide technical guidance and support to internal teams and partner with Product Marketing on roadmap direction and developer value propositions.   Engage with customers, partners, and key stakeholders to gather requirements, understand pain points, and gather feedback on product features and functionality.   Collaborate with Product Marketing, Sales, and Marketing teams to develop compelling product messaging, positioning, and go-to-market strategies.   Conduct product demonstrations, workshops, and training sessions for internal teams and external audiences.   Stay abreast of industry trends, emerging technologies, and competitive landscape to identify opportunities for product differentiation and innovation.   Conduct competitive analysis to understand strengths and weaknesses of competing products, and leverage insights to inform product strategy and positioning.    Requirements:    3-5 years of experience in a technical product management/product owner role, preferably in a software company, with an ability to drive product planning, push development, and release products   Bachelor’s degree or the equivalent experience   Experience working within a cross functional organization and understanding the needs of multiple teams   Excellent organizational and analytical skills, with the ability to evolve product roadmap based on research, data and industry trends   Experience participating in a Product Development lifecycle within an agile development framework   A self-starter who can manage priorities independently, learn new technologies, and adapt to a fast-paced work environment.    Assets:    Experience with document processing tools, SDKs, APIs, or other developer-focused products is a plus   Experience in a QA Engineer, Developer, Solution/Sales Engineer, or similar role in a tech company.    Benefits:    Competitive salary commensurate with experience and qualifications.   A comprehensive extended benefits package including health, dental and vision for you and your family, with company paid offerings.   401K savings program with company match.   Generous paid time off (PTO) is offered to support the ability to rest and recharge.   A great team environment and resources, supporting you to do the best work of your life and providing unlimited career growth potential.   Highly autonomous and entrepreneurial environment.   Annual recurring WFH allowance for you to purchase items you need for your home office.   Ongoing support for learning development so you can master your craft.   Work with the hardware you're most comfortable with (Windows or Mac).   Diverse and inclusive workplace where we all learn from each other.   Company Description  As the industry-leading p ...

# %% [markdown]
# #### Step 3: Template Some Prompt Engineering
# ##### - this is where we get <span style="color:blue">Gemini</span> involved. We're using the same prompt as before - apples to apples.
# ##### Again: let <span style="color:blue">Gemini</span> talk to <span style="color:blue">Gemini</span>.
# ***

# %%
# making up a random "lambda" function to create the variable "prompt_template"

# the text is what I would be putting into Gemini were I to do this one job at a time - prompt engineering

prompt_template = lambda resume_string, job_desc_string : f"""
### Role: 
You are a professional resume optimization expert, tailoring my resume to fit specific job descriptions. 
You know my job preferences include collaborating with people, and helping businesses get the most out of their data.
Your goal is to optimize my resume and provide actionable suggestions for improvement to align with the target role.

### Guidelines:
1. **Relevance**:
    - Prioritize the particular skills and experiences I have with what is **most relevant to the job position**.
    - De-emphasize or even completely remove irrelevant details to ensure a **concise** and **targeted** resume.
    - Limit work experience section to 2-3 most relevant roles
    - Limit bullet points under each role to 2-3 most relevant impacts
    - Select only the core competencies most relevant to the job description

2. **Action-Driven Results**:
    - Choose **strong action verbs** and **quantifiable results** (eg: percentages, revenues, efficiency improvement, etc.)

3. **Keyword Optimization**:
    - Integrate **keywords** and phrases from the job description naturally to optimize for Applicant Tracking Systems (ATS)

4. **Additional Suggestions*** *(if gaps exist)*:
    - If the resume does not fully align with the job description, suggest:
        a.) **Additional technical or soft skills** that I could add to make my profile stronger.
        b.) **Certifications or courses** I have (or could pursue) that would bridge the gap(s).
        c.) **Project ideas or experiences** that would better align with the role.

5.) **Formatting**:
    - Ouptut the tailored resume in **clean Markdown format**.
    - Include an **"Additional Suggestions"** section at the end with actionable improvement recommendations.

---

## Input:
- **My resume**:
{resume_string}

- **The Job Description**:
{job_desc_string}

---

### Output:
1. **Tailored Resume**:
    - A resume in **Markdown format** that emphasizes relevant experience, skills, and achievements.
    - Incorporates job description **keywords** to optimize for ATS.
    - Uses confident language and is no longer than **one page**.

2. **Additional Suggestions** *(if applicable)*:
    - List **skills** that could strengthen alignment with the role.
    - Recommend **certifications or courses** to pursue.
    - Suggest **specific projects or experiences** to develop.
"""

# %% [markdown]
# #### It helps to make the prompt template a variable for the messaging...
# ***

# %%
prompt = prompt_template(resume_string, job_desc_string)

# %% [markdown]
# ### Step 4: Generate the Resume with <span style="color:blue">Gemini</span>
# ***

# %%
# set up the client with the environment variable
gemini_api_key = os.environ.get("GEMINI_API_KEY")

genai.configure(api_key = gemini_api_key)

# great tip here, from Gemini itself: check if the API key is set:
if not gemini_api_key: 
    raise ValueError("GEMINI_API_KEY environment variable is not set. Please set it, and restart the kernel.")

genai.configure(api_key = gemini_api_key)

# make the call and instantiate the model (make it an object)

model = genai.GenerativeModel("gemini-2.0-flash")

# set a response variable to hold the info that comes back

response = model.generate_content(
    prompt, 
    generation_config = genai.types.GenerationConfig(temperature = 0.7)
)

# get the response

reponse_string = response.text

print(response.text)
# Out:
# ```markdown
# ## Nicholas Joseph
# Product Manager | Servant Leader | Tech Enthusiast
#
# Email: [nickpjoseph210@gmail.com](mailto:nickpjoseph210@gmail.com) | Phone: (210) 771-9853 | LinkedIn: [nickjoseph](https://www.linkedin.com/in/nickjoseph) | [GitHub](https://github.com/npj210mlk)
#
# ## Summary
#
# Mission-focused Product Manager with a proven history of delivering data products and developer SDK solutions through clear product strategy and vision. Strong background in stakeholder engagement, cross-functional communication, and Agile methodologies. Adept at translating business needs into actionable requirements for development teams.
#
# ## Skills
#
# **Product Management:** Agile Methodologies (Scrum), Go-to-Market Strategy, Data Analysis and Visualization, Backlog Refinement, A/B Testing, KPI Development, Roadmap Development, User Story Creation, Acceptance Criteria Definition
# **Technical:** SQL, Python, Tableau, ETL, Cloud Computing, API Integrations, Jira, Trello
# **Soft Skills:** Stakeholder Management, Leadership and Mentoring, Presentation Skills, Cross-functional Collaboration, Negotiation / Budgeting, Conflict Resolution
#
# ## Experience
#
# **Cloud Data Engineer** Data Clymer (now Spaulding Ridge), Remote | 07/2022 - 06/2023
#
# *   Collaboratively implemented data pipelines for the NFL, MLB, and ACLU through Scaled Agile, resulting in improved source data extraction times by 98.9%.
# *   Facilitated Agile ceremonies for the client while spearheading a database upgrade project for a Multimedia company that reduced source extraction times and reporting accuracy by 53%.
#
# **Data Engineer** Gathi Analytics (now Apexon), Remote | 12/2020 - 03/2022
#
# *   Transforming banking data from legacy systems to cloud-based architecture (e.g.: Snowflake).
# *   Presenting data lineage / integrity to bank regulators to assure performance compliance.
#
# ## Education
#
# Certificate of Completion - PMP Exam Prep - 35 PDU Technical Institute of America, Remote | 2024
# Certificate of Completion - Data Science Codeup, San Antonio, TX | 2020
# Bachelor's - Biology Concordia University, Austin, TX | 2001
#
# ## Additional Suggestions
#
# *   **Skills:**
#     *   Consider adding specific document processing SDKs or API experience to your skills section.
#     *   Highlight any experience with developer-focused products or tools.
# *   **Projects/Experience:**
#     *   If you have any personal projects involving SDKs, APIs, or document processing, consider adding them to showcase your abilities.
#     *   If you have examples of defining product requirements, user stories, and acceptance criteria, include them in your experience bullet points.
# *   **Certifications/Courses:**
#     *   Look into certifications related to specific SDKs or API platforms relevant to the document processing industry.
# ```

# %% [markdown]
# ### Step 5: Show the Results
# #### (after separating the new resume from AI improvement suggestions, of course)
# ***

# %%
# separation
response_list = response_string.split("## Additional Suggestions")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 2
#       1 # separation
# ----> 2 response_list = response_string.split("## Additional Suggestions")
#
# NameError: name 'response_string' is not defined
